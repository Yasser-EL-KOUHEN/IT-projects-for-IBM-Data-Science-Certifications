# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Like you can see, the name of this file answers to this exercise

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List popular Data Science libraries
# - List popular Data Science tools

# %% [markdown]
# In this notebook, Data Science tools are summarized.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are :
#    1.  Python
#    2.  R
#    3.  SQL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#    1. Matplotlib.pyplot in Python language for Data Visualization
#    2. Tensorflow in Python language for Deep Learning
#    3. Datasets in R language in order to have some examples of data sets to train on

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# |Data Science Tools|
# |-------|
# |Rstudio|
# |MySQL|
# |Jupyter Notebooks|
# |Visual Studio Code (also known as VScode)|
#
#
# These are 3 development environment open source tools

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
10-4
# Out:
# 6

# %%
pow(5,3)
# Out:
# 125

# %%
78//7
# Out:
# 11

# %%
78%7
# Out:
# 1

# %%
-35+47
# Out:
# 12

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#This is a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#This will convert 200 minutes to hours by diving by 60
(200/60)
# Out:
# 3.3333333333333335

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To see the answer of this question, ge see below the question header of the exercise 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Author :
# Yasser EL KOUHEN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
